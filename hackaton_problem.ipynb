# %%
from hackathon_qaoa import _create_problem, _relax_problem

from hackathon_qaoa import standard_qaoa, ibm_simulator_qaoa, ibm_ku_qaoa, ibm_jakarta_qaoa
import numpy as np

# %%
# clustering, 2heads, 4 elements
p = 10

weight = np.array([1, 5, 7, 4, 10, 2, 9, 6])

# 0<=w, w~10^0

mu = np.array([-p] * 8) - weight

sigma = np.array(
    [
        [0, 0, 0, 0, p, 0, 0, 0],
        [0, 0, 0, 0, 0, p, 0, 0],
        [0, 0, 0, 0, 0, 0, p, 0],
        [0, 0, 0, 0, 0, 0, 0, p],
        [p, 0, 0, 0, 0, 0, 0, 0],
        [0, p, 0, 0, 0, 0, 0, 0],
        [0, 0, p, 0, 0, 0, 0, 0],
        [0, 0, 0, p, 0, 0, 0, 0],
    ]
)

# %%
# matching,33 
p = 10

weight = np.array([8, 1, 5, 5, 2, 7, 1, 6, 4])

# 0<=w, w~10^0

mu = np.array([-p] * 9) - weight

sigma = np.array(
    [
        [0, p, p, p, 0, 0, p, 0, 0],
        [p, 0, p, 0, p, 0, 0, p, 0],
        [p, p, 0, 0, 0, p, 0, 0, p],
        [p, 0, 0, 0, p, p, p, 0, 0],
        [0, p, 0, p, 0, p, 0, p, 0],
        [0, 0, p, p, p, 0, 0, 0, p],
        [p, 0, 0, p, 0, 0, 0, p, p],
        [0, p, 0, 0, p, 0, p, 0, p],
        [0, 0, p, 0, 0, p, p, p, 0],
    ]
)

# %%
standard_qaoa(mu, sigma)
# Out:
# optimal function value: -51.0
# optimal value: [1. 0. 0. 0. 0. 1. 0. 1. 0.]
# status: SUCCESS

# %%
result_ku_match = ibm_ku_qaoa(mu, sigma)
# Out:
# ibmqfactory.load_account:WARNING:2022-06-29 00:19:36,081: Credentials are already in use. The existing account in the session will be replaced.

# %%
fval_list = [s.fval for s in result_sim.samples]

# %%
cluster_QAOA_simul_fval_list = fval_list

# %%
import matplotlib.pyplot as plt
import mplhep
plt.style.use(mplhep.style.LHCb2)  # CMS or ATLAS/LHCb

plt.plot([], [], ' ', label='Matching QAOA Simulator')

plt.plot(fval_list, 'o-')
plt.xlabel('$\leftarrow$ Optimized')
plt.ylabel('f Value')
plt.legend()
plt.savefig("MatchQAOASimul.pdf")
plt.show()
